# %% [markdown]
# Using similarity distance algorithms from https://pypi.org/project/textdistance/ and https://itnext.io/string-similarity-the-basic-know-your-algorithms-guide-3de3d7346227

# %% [markdown]
# The strings representing the itineraries ...
# Bob	            AAAABBCCCCCCCCCBBAAEEAAA
# Jane	        ABBCCCCCCCEECCCCBBAAAAAA
# Ralph	        FFFFFBJJCCCCECCCCJJFFFFF
# Lisa            GGGGGBKKKKKEKKKKBGGGGGGG
# Michael  		HHHHHLLLLHHHHHHHHHHHHHHH

# %% [markdown]
# ![Anaconda-textdistancetest.png](attachment:Anaconda-textdistancetest.png)

# %%
import textdistance

# %% [markdown]
# bag	token_based
# cosine	token_based
# jaccard	token_based
# monge_elkan	token_based
# overlap	token_based
# sorensen	token_based
# sorensen_dice	token_based
# tanimoto	token_based
# tversky	token_based
# identity	simple
# length	simple
# matrix	simple
# postfix	simple
# prefix	simple
# lcsseq	sequence_based
# lcsstr	sequence_based
# ratcliff_obershelp	sequence_based
# editex	phonetic
# mra	phonetic
# damerau_levenshtein	edit_based
# gotoh	edit_based
# hamming	edit_based
# jaro	edit_based
# jaro_winkler	edit_based
# levenshtein	edit_based
# mlipns	edit_based
# needleman_wunsch	edit_based
# smith_waterman	edit_based
# strcmp95	edit_based
# arith_ncd	compression_based
# bwtrle_ncd	compression_based
# bz2_ncd	compression_based
# entropy_ncd	compression_based
# lzma_ncd	compression_based
# rle_ncd	compression_based
# sqrt_ncd	compression_based
# zlib_ncd	compression_based

# %%
# print( help(textdistance ))

# %% [markdown]
# https://en.wikipedia.org/wiki/Hamming_distance

# %%
print (textdistance.hamming('AAAABBCCCCCCCCCBBAAEEAAA', 'ABBCCCCCCCEECCCCBBAAAAAA'))
print (textdistance.hamming('AAAABBCCCCCCCCCBBAAEEAAA', 'FFFFFBJJCCCCECCCCJJFFFFF'))
# Out:
# 11
# 17

# %% [markdown]
# https://en.wikipedia.org/wiki/Levenshtein_distance

# %%
print (textdistance.levenshtein('AAAABBCCCCCCCCCBBAAEEAAA', 'ABBCCCCCCCEECCCCBBAAAAAA'))
print (textdistance.levenshtein('AAAABBCCCCCCCCCBBAAEEAAA', 'FFFFFBJJCCCCECCCCJJFFFFF'))
# Out:
# 9
# 17

# %%
http://collaboration.cmc.ec.gc.ca/science/rpn/biblio/ddj/Website/articles/DDJ/1988/8807/8807c/8807c.htm

# %%
print (textdistance.ratcliff_obershelp('AAAABBCCCCCCCCCBBAAEEAAA', 'ABBCCCCCCCEECCCCBBAAAAAA'))
print (textdistance.ratcliff_obershelp('AAAABBCCCCCCCCCBBAAEEAAA', 'FFFFFBJJCCCCECCCCJJFFFFF'))
# Out:
# 0.7916666666666666
# 0.375
