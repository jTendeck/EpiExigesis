# %%
import os
print(os.getcwd())

datadir='D:\\Projects\\AngelHack\\python\\'
print(datadir)

# %%
f = open(datadir + 'testdata-01.txt', 'r')
contents = f.readline()
contentsplit=contents.split('\t')
print(contentsplit)
print(f.read())
f.closed
# Out:
# ['Bob', '00:00', 'A\n']
# Bob	01:00	A
# Bob	02:00	A
# Bob	03:00	A
# Bob	04:00	B
# Bob	05:00	B
# Bob	06:00	C
# Bob	07:00	C
# Bob	08:00	C
# Bob	09:00	C
# Bob	10:00	C
# Bob	11:00	C
# Bob	12:00	C
# Bob	13:00	C
# Bob	14:00	C
# Bob	15:00	B
# Bob	16:00	B
# Bob	17:00	A
# Bob	18:00	A
# Bob	19:00	E
# Bob	20:00	E
# Bob	21:00	A
# Bob	22:00	A
# Bob	23:00	A
# Jane	00:00	A
# Jane	01:00	B
# Jane	02:00	B
# Jane	03:00	C
# Jane	04:00	C
# Jane	05:00	C
# Jane	06:00	C
# Jane	07:00	C
# Jane	08:00	C
# Jane	09:00	C
# Jane	10:00	E
# Jane	11:00	E
# Jane	12:00	C
# Jane	13:00	C
# Jane	14:00	C
# Jane	15:00	C
# Jane	16:00	B
# Jane	17:00	B
# Jane	18:00	A
# Jane	19:00	A
# Jane	20:00	A
# Jane	21:00	A
# Jane	22:00	A
# Jane	23:00	A
# Ralph	00:00	F
# Ralph	01:00	F
# Ralph	02:00	F
# Ralph	03:00	F
# Ralph	04:00	F
# Ralph	05:00	B
# Ralph	06:00	J
# Ralph	07:00	J
# Ralph	08:00	C
# Ralph	09:00	C
# Ralph	10:00	C
# Ralph	11:00	C
# Ralph	12:00	E
# Ralph	13:00	C
# Ralph	14:00	C
# Ralph	15:00	C
# Ralph	16:00	C
# Ralph	17:00	J
# Ralph	18:00	J
# Ralph	19:00	F
# Ralph	20:00	F
# Ralph	21:00	F
# Ralph	22:00	F
# Ralph	23:00	F
# Lisa	00:00	G
# Lisa	01:00	G
# Lisa	02:00	G
# Lisa	03:00	G
# Lisa	04:00	G
# Lisa	05:00	B
# Lisa	06:00	K
# Lisa	07:00	K
# Lisa	08:00	K
# Lisa	09:00	K
# Lisa	10:00	K
# Lisa	11:00	E
# Lisa	12:00	K
# Lisa	13:00	K
# Lisa	14:00	K
# Lisa	15:00	K
# Lisa	16:00	B
# Lisa	17:00	G
# Lisa	18:00	G
# Lisa	19:00	G
# Lisa	20:00	G
# Lisa	21:00	G
# Lisa	22:00	G
# Lisa	23:00	G
# Michael	00:00	H
# Michael	01:00	H
# Michael	02:00	H
# Michael	03:00	NoData
# Michael	04:00	H
# Michael	05:00	H
# Michael	06:00	L
# Michael	07:00	L
# Michael	08:00	L
# Michael	09:00	L
# Michael	10:00	H
# Michael	11:00	H
# Michael	12:00	H
# Michael	13:00	H
# Michael	14:00	H
# Michael	15:00	H
# Michael	16:00	H
# Michael	17:00	H
# Michael	18:00	H
# Michael	19:00	H
# Michael	20:00	H
# Michael	21:00	H
# Michael	22:00	H
# Michael	23:00	H
# False

# %%
events=[]
filepath = datadir + 'testdata-01.txt'
with open(filepath) as fp:  
    for cnt, line in enumerate(fp):
        linestripped=line.strip()
        linesplit=linestripped.split('\t')
        events.append(linesplit)
        # print(cnt, linesplit)
print(events)
# Out:
# [['Bob', '00:00', 'A'], ['Bob', '01:00', 'A'], ['Bob', '02:00', 'A'], ['Bob', '03:00', 'A'], ['Bob', '04:00', 'B'], ['Bob', '05:00', 'B'], ['Bob', '06:00', 'C'], ['Bob', '07:00', 'C'], ['Bob', '08:00', 'C'], ['Bob', '09:00', 'C'], ['Bob', '10:00', 'C'], ['Bob', '11:00', 'C'], ['Bob', '12:00', 'C'], ['Bob', '13:00', 'C'], ['Bob', '14:00', 'C'], ['Bob', '15:00', 'B'], ['Bob', '16:00', 'B'], ['Bob', '17:00', 'A'], ['Bob', '18:00', 'A'], ['Bob', '19:00', 'E'], ['Bob', '20:00', 'E'], ['Bob', '21:00', 'A'], ['Bob', '22:00', 'A'], ['Bob', '23:00', 'A'], ['Jane', '00:00', 'A'], ['Jane', '01:00', 'B'], ['Jane', '02:00', 'B'], ['Jane', '03:00', 'C'], ['Jane', '04:00', 'C'], ['Jane', '05:00', 'C'], ['Jane', '06:00', 'C'], ['Jane', '07:00', 'C'], ['Jane', '08:00', 'C'], ['Jane', '09:00', 'C'], ['Jane', '10:00', 'E'], ['Jane', '11:00', 'E'], ['Jane', '12:00', 'C'], ['Jane', '13:00', 'C'], ['Jane', '14:00', 'C'], ['Jane', '15:00', 'C'], ['Jane', '16:00', 'B'], ['Jane', '17:00', 'B'], ['Jane', '18:00', 'A'], ['Jane', '19:00', 'A'], ['Jane', '20:00', 'A'], ['Jane', '21:00', 'A'], ['Jane', '22:00', 'A'], ['Jane', '23:00', 'A'], ['Ralph', '00:00', 'F'], ['Ralph', '01:00', 'F'], ['Ralph', '02:00', 'F'], ['Ralph', '03:00', 'F'], ['Ralph', '04:00', 'F'], ['Ralph', '05:00', 'B'], ['Ralph', '06:00', 'J'], ['Ralph', '07:00', 'J'], ['Ralph', '08:00', 'C'], ['Ralph', '09:00', 'C'], ['Ralph', '10:00', 'C'], ['Ralph', '11:00', 'C'], ['Ralph', '12:00', 'E'], ['Ralph', '13:00', 'C'], ['Ralph', '14:00', 'C'], ['Ralph', '15:00', 'C'], ['Ralph', '16:00', 'C'], ['Ralph', '17:00', 'J'], ['Ralph', '18:00', 'J'], ['Ralph', '19:00', 'F'], ['Ralph', '20:00', 'F'], ['Ralph', '21:00', 'F'], ['Ralph', '22:00', 'F'], ['Ralph', '23:00', 'F'], ['Lisa', '00:00', 'G'], ['Lisa', '01:00', 'G'], ['Lisa', '02:00', 'G'], ['Lisa', '03:00', 'G'], ['Lisa', '04:00', 'G'], ['Lisa', '05:00', 'B'], ['Lisa', '06:00', 'K'], ['Lisa', '07:00', 'K'], ['Lisa', '08:00', 'K'], ['Lisa', '09:00', 'K'], ['Lisa', '10:00', 'K'], ['Lisa', '11:00', 'E'], ['Lisa', '12:00', 'K'], ['Lisa', '13:00', 'K'], ['Lisa', '14:00', 'K'], ['Lisa', '15:00', 'K'], ['Lisa', '16:00', 'B'], ['Lisa', '17:00', 'G'], ['Lisa', '18:00', 'G'], ['Lisa', '19:00', 'G'], ['Lisa', '20:00', 'G'], ['Lisa', '21:00', 'G'], ['Lisa', '22:00', 'G'], ['Lisa', '23:00', 'G'], ['Michael', '00:00', 'H'], ['Michael', '01:00', 'H'], ['Michael', '02:00', 'H'], ['Michael', '03:00', 'NoData'], ['Michael', '04:00', 'H'], ['Michael', '05:00', 'H'], ['Michael', '06:00', 'L'], ['Michael', '07:00', 'L'], ['Michael', '08:00', 'L'], ['Michael', '09:00', 'L'], ['Michael', '10:00', 'H'], ['Michael', '11:00', 'H'], ['Michael', '12:00', 'H'], ['Michael', '13:00', 'H'], ['Michael', '14:00', 'H'], ['Michael', '15:00', 'H'], ['Michael', '16:00', 'H'], ['Michael', '17:00', 'H'], ['Michael', '18:00', 'H'], ['Michael', '19:00', 'H'], ['Michael', '20:00', 'H'], ['Michael', '21:00', 'H'], ['Michael', '22:00', 'H'], ['Michael', '23:00', 'H']]

# %%
agentsextract=[]
for cnt, line in enumerate(events):
    agentsextract.append(line[0])
# print(agentsextract)
agentlist = list( dict.fromkeys(agentsextract) )
print(agentlist) 

intervalextract=[]
for cnt, line in enumerate(events):
    intervalextract.append(line[1])
# print(agentsextract)
intervallist = list( dict.fromkeys(intervalextract) )
print(intervallist) 

placeextract=[]
for cnt, line in enumerate(events):
    placeextract.append(line[2])
# print(agentsextract)
placelist = list( dict.fromkeys(placeextract) )
print(placelist)
# Out:
# ['Bob', 'Jane', 'Ralph', 'Lisa', 'Michael']
# ['00:00', '01:00', '02:00', '03:00', '04:00', '05:00', '06:00', '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', '20:00', '21:00', '22:00', '23:00']
# ['A', 'B', 'C', 'E', 'F', 'J', 'G', 'K', 'H', 'NoData', 'L']

# %%
agent = 'Bob'   # agent 'fixed'
print( 'Agent is  ' , agent )
for cnt, interval in enumerate(intervallist): # Iterate over Interval list
    print( agent,  " at Interval:",  interval )
    for cnt2, agentother in enumerate(agentlist): # Iterate over Agent list
        
        if agent != agentother:
            # print( cnt2, agentother  )
            # print( agent != agentother , agent, agentother )
        
            
            for cnt3, event in enumerate(events):  #Find place of current agent
                if event[0] == agent and event[1] == interval:
                    # print(event)
                    agentplace = event[2]
    print('Agent ', agent, ' is at ', agentplace)
    
    score = 0
    for cnt4, event in enumerate(events):  #Find  other agent at place at that interval
        
        if event[1] == interval and event[2] == agentplace and event[0] != agent:
            print( "  ", event[0], ' is also at '  , event[2] )
            score = score + 1
        
    print( agent, ' exposure score during ', interval, ' at ', agentplace,  ' is ' , score)
    print()
            
        


# print( agents)
# Out:
# Agent is   Bob
# Bob  at Interval: 00:00
# Agent  Bob  is at  A
#    Jane  is also at  A
# Bob  exposure score during  00:00  at  A  is  1
#
# Bob  at Interval: 01:00
# Agent  Bob  is at  A
# Bob  exposure score during  01:00  at  A  is  0
#
# Bob  at Interval: 02:00
# Agent  Bob  is at  A
# Bob  exposure score during  02:00  at  A  is  0
#
# Bob  at Interval: 03:00
# Agent  Bob  is at  A
# Bob  exposure score during  03:00  at  A  is  0
#
# Bob  at Interval: 04:00
# Agent  Bob  is at  B
# Bob  exposure score during  04:00  at  B  is  0
#
# Bob  at Interval: 05:00
# Agent  Bob  is at  B
#    Ralph  is also at  B
#    Lisa  is also at  B
# Bob  exposure score during  05:00  at  B  is  2
#
# Bob  at Interval: 06:00
# Agent  Bob  is at  C
#    Jane  is also at  C
# Bob  exposure score during  06:00  at  C  is  1
#
# Bob  at Interval: 07:00
# Agent  Bob  is at  C
#    Jane  is also at  C
# Bob  exposure score during  07:00  at  C  is  1
#
# Bob  at Interval: 08:00
# Agent  Bob  is at  C
#    Jane  is also at  C
#    Ralph  is also at  C
# Bob  exposure score during  08:00  at  C  is  2
#
# Bob  at Interval: 09:00
# Agent  Bob  is at  C
#    Jane  is also at  C
#    Ralph  is also at  C
# Bob  exposure score during  09:00  at  C  is  2
#
# Bob  at Interval: 10:00
# Agent  Bob  is at  C
#    Ralph  is also at  C
# Bob  exposure score during  10:00  at  C  is  1
#
# Bob  at Interval: 11:00
# Agent  Bob  is at  C
#    Ralph  is also at  C
# Bob  exposure score during  11:00  at  C  is  1
#
# Bob  at Interval: 12:00
# Agent  Bob  is at  C
#    Jane  is also at  C
# Bob  exposure score during  12:00  at  C  is  1
#
# Bob  at Interval: 13:00
# Agent  Bob  is at  C
#    Jane  is also at  C
#    Ralph  is also at  C
# Bob  exposure score during  13:00  at  C  is  2
#
# Bob  at Interval: 14:00
# Agent  Bob  is at  C
#    Jane  is also at  C
#    Ralph  is also at  C
# Bob  exposure score during  14:00  at  C  is  2
#
# Bob  at Interval: 15:00
# Agent  Bob  is at  B
# Bob  exposure score during  15:00  at  B  is  0
#
# Bob  at Interval: 16:00
# Agent  Bob  is at  B
#    Jane  is also at  B
#    Lisa  is also at  B
# Bob  exposure score during  16:00  at  B  is  2
#
# Bob  at Interval: 17:00
# Agent  Bob  is at  A
# Bob  exposure score during  17:00  at  A  is  0
#
# Bob  at Interval: 18:00
# Agent  Bob  is at  A
#    Jane  is also at  A
# Bob  exposure score during  18:00  at  A  is  1
#
# Bob  at Interval: 19:00
# Agent  Bob  is at  E
# Bob  exposure score during  19:00  at  E  is  0
#
# Bob  at Interval: 20:00
# Agent  Bob  is at  E
# Bob  exposure score during  20:00  at  E  is  0
#
# Bob  at Interval: 21:00
# Agent  Bob  is at  A
#    Jane  is also at  A
# Bob  exposure score during  21:00  at  A  is  1
#
# Bob  at Interval: 22:00
# Agent  Bob  is at  A
#    Jane  is also at  A
# Bob  exposure score during  22:00  at  A  is  1
#
# Bob  at Interval: 23:00
# Agent  Bob  is at  A
#    Jane  is also at  A
# Bob  exposure score during  23:00  at  A  is  1
